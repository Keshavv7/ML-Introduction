# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
# We can see there are no null values
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# <b> Performing EDA </b>

# %%
# Let us draw a correlation plot to check for dependence among variables
plt.figure(figsize=(11,9))
sns.heatmap(df.corr(), annot = True, fmt=".3f", cmap = "YlGnBu")
plt.title("Correlation Heatmap")
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
# Exploring Pregnancy and target variables
plt.figure(figsize=(11,9))
# Plotting density function graph
kde = sns.kdeplot(df['Pregnancies'][df['Outcome']==1], color = 'Red', shade = True)
kde1 = sns.kdeplot(df['Pregnancies'][df['Outcome']==0], color = 'Blue', shade = True)
kde.set_xlabel('Pregnancies')
kde.set_ylabel('Density')
kde.legend(['Positive', 'Negative'])
# Out:
# /tmp/ipykernel_4436/90443920.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kde = sns.kdeplot(df['Pregnancies'][df['Outcome']==1], color = 'Red', shade = True)
# /tmp/ipykernel_4436/90443920.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kde1 = sns.kdeplot(df['Pregnancies'][df['Outcome']==0], color = 'Blue', shade = True)

# %%
# Exploring Glucose and target variables
plt.figure(figsize=(11,9))
sns.violinplot(data=df, x='Outcome', y='Glucose', split=True, linewidth=2, inner='quartile')
# Out:
# <Axes: xlabel='Outcome', ylabel='Glucose'>

# %%
plt.figure(figsize=(11,9))
# Plotting density function graph
kde = sns.kdeplot(df['Glucose'][df['Outcome']==1], color = 'Red', shade = True)
kde1 = sns.kdeplot(df['Glucose'][df['Outcome']==0], color = 'Blue', shade = True)
kde.set_xlabel('Glucose')
kde.set_ylabel('Density')
kde.legend(['Positive', 'Negative'])
# Out:
# /tmp/ipykernel_4436/1634352808.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kde = sns.kdeplot(df['Glucose'][df['Outcome']==1], color = 'Red', shade = True)
# /tmp/ipykernel_4436/1634352808.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kde1 = sns.kdeplot(df['Glucose'][df['Outcome']==0], color = 'Blue', shade = True)

# %% [markdown]
# Now we can see that features like Glucose, BoodPressure, Insulin, BMI, SkinThickness, Age might have 0 values. This behavior is obviously absurd and hence needs to be changed.

# %% [markdown]
# One way to tackle this is to fill these fields with either mean or median values.

# %%
# Replacing zero values with mean/median
cols_for_median = ['Glucose', 'BloodPressure', 'Age']
cols_for_mean = ['BMI', 'SkinThickness', 'Insulin']
for col in cols_for_median:
    df[col] = df[col].replace(0, df[col].median())
for col in cols_for_mean:
    df[col] = df[col].replace(0, df[col].mean())
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0              6      148             72      35.000000   79.799479  33.6
# 1              1       85             66      29.000000   79.799479  26.6
# 2              8      183             64      20.536458   79.799479  23.3
# 3              1       89             66      23.000000   94.000000  28.1
# 4              0      137             40      35.000000  168.000000  43.1
# ..           ...      ...            ...            ...         ...   ...
# 763           10      101             76      48.000000  180.000000  32.9
# 764            2      122             70      27.000000   79.799479  36.8
# 765            5      121             72      23.000000  112.000000  26.2
# 766            1      126             60      20.536458   79.799479  30.1
# 767            1       93             70      31.000000   79.799479  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  121.656250      72.386719      26.606479  118.660163
# std       3.369578   30.438286      12.096642       9.631241   93.080358
# min       0.000000   44.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.750000      64.000000      20.536458   79.799479
# 50%       3.000000  117.000000      72.000000      23.000000   79.799479
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    32.450805                  0.471876   33.240885    0.348958
# std      6.875374                  0.331329   11.760232    0.476951
# ...

# %%
# Plotting Insulin

plt.rcParams.update({'figure.figsize':(7,5), 'figure.dpi':100})
plt.hist(df['Insulin'], bins=100)
plt.gca().set(title='Insulin Distribution', ylabel='Frequency')
# Out:
# [Text(0.5, 1.0, 'Insulin Distribution'), Text(0, 0.5, 'Frequency')]

# %%
# Plotting BMI
plt.rcParams.update({'figure.figsize':(7,5), 'figure.dpi':100})
plt.hist(df['BMI'], bins=100)
plt.gca().set(title='BMI Frequency Distribution', ylabel='Frequency')
# Out:
# [Text(0.5, 1.0, 'BMI Frequency Distribution'), Text(0, 0.5, 'Frequency')]

# %%
# We may drop some outliers from the data for better results

df = df[df['BMI']<55]
df = df[df['Insulin']<400]
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   744.000000  744.000000     744.000000     744.000000  744.000000
# mean      3.875000  120.526882      72.337366      26.288677  107.462373
# std       3.379013   29.872215      11.934564       9.431414   61.707279
# min       0.000000   44.000000      24.000000       7.000000   15.000000
# 25%       1.000000   99.000000      64.000000      20.536458   79.799479
# 50%       3.000000  116.000000      72.000000      22.000000   79.799479
# 75%       6.000000  139.000000      80.000000      32.000000  120.000000
# max      17.000000  199.000000     122.000000      99.000000  392.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  744.000000                744.000000  744.000000  744.000000
# mean    32.202982                  0.464681   33.270161    0.340054
# std      6.572633                  0.313136   11.738555    0.474046
# ...

# %%
X = df.drop(['Outcome'], axis='columns')
X
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0              6      148             72      35.000000   79.799479  33.6
# 1              1       85             66      29.000000   79.799479  26.6
# 2              8      183             64      20.536458   79.799479  23.3
# 3              1       89             66      23.000000   94.000000  28.1
# 4              0      137             40      35.000000  168.000000  43.1
# ..           ...      ...            ...            ...         ...   ...
# 763           10      101             76      48.000000  180.000000  32.9
# 764            2      122             70      27.000000   79.799479  36.8
# 765            5      121             72      23.000000  112.000000  26.2
# 766            1      126             60      20.536458   79.799479  30.1
# 767            1       93             70      31.000000   79.799479  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# ...

# %%
y = df['Outcome']
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 744, dtype: int64

# %% [markdown]
# <b> Now we can test several models and choose the best one for our usage </b>

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier

# %%
#JSON for all models

model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto'),
        'params' : {
            'C': [1,10,20],
            'kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(multi_class='auto'),
        'params': {
            'C': [1,5,10],
            'solver': ['lbfgs', 'liblinear']
        }
    },
    'mlp_classifier': {
        'model' : MLPClassifier(random_state=42),
        'params' : {
            'activation': ['logistic', 'relu'],
            'max_iter': [4500,8000]
        }
    }
}

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV

# %%
scaler = StandardScaler()
scores = []
for model_name, mp in model_params.items():
    # Create a pipeline with the scaler and the model
    pipeline = Pipeline([
        ('scaler', scaler),
        ('model', mp['model'])
    ])

    # Define the parameter grid including both scaler and model parameters
    param_grid = {
        'scaler__with_mean': [True, False]
    }
    param_grid.update({f'model__{key}': value for key, value in mp['params'].items()})  
    # Add model-specific parameters

    # Create the GridSearchCV object with the pipeline
    clf = GridSearchCV(pipeline, param_grid, cv=5, return_train_score=False)
    clf.fit(X, y)
    
    scores.append({
        'model': model_name,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })

df_scores = pd.DataFrame(scores, columns=['model', 'best_score', 'best_params'])
df_scores
# Out:
#                  model  best_score  \
# 0                  svm    0.772855
# 1        random_forest    0.749955
# 2  logistic_regression    0.776873
# 3       mlp_classifier    0.778215
#
#                                          best_params
# 0  {'model__C': 1, 'model__kernel': 'rbf', 'scale...
# 1  {'model__n_estimators': 10, 'scaler__with_mean...
# 2  {'model__C': 1, 'model__solver': 'lbfgs', 'sca...
# 3  {'model__activation': 'logistic', 'model__max_...

# %%
max_score_index = df_scores['best_score'].idxmax()

# %%
for i in range(len(model_params)):
    if i==max_score_index:
        print("The best results are obtained by: ")
    print("Model Name:",df_scores.at[i,'model'])
    print("Model Score:",df_scores.at[i,'best_score'])
    print("Parameters:",df_scores.at[i,'best_params'])
    print("\n")
# Out:
# Model Name: svm
# Model Score: 0.7728550698349356
# Parameters: {'model__C': 1, 'model__kernel': 'rbf', 'scaler__with_mean': True}
#
#
# Model Name: random_forest
# Model Score: 0.7499546526392165
# Parameters: {'model__n_estimators': 10, 'scaler__with_mean': True}
#
#
# Model Name: logistic_regression
# Model Score: 0.7768728460003628
# Parameters: {'model__C': 1, 'model__solver': 'lbfgs', 'scaler__with_mean': True}
#
#
# The best results are obtained by:
# Model Name: mlp_classifier
# Model Score: 0.7782151278795574
# Parameters: {'model__activation': 'logistic', 'model__max_iter': 4500, 'scaler__with_mean': True}

# %%
#Hence we shall use Neural Networks as our model
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import make_pipeline

# We now define our final model
final_model = make_pipeline(StandardScaler(), MLPClassifier(activation='logistic', max_iter=4500))

scores = cross_val_score(final_model, X, y, cv=5)
print("Average Score of our model =", round(np.average(scores), 4)*100, "%")
# Out:
# Average Score of our model = 77.82 %
