# %%
import quandl
quandl.ApiConfig.api_key = "fw5nDw6r11iFdURq7ya3"
data = quandl.get_table('MER/F1', compnumber = "39102", paginate = True)
print(data)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6380\1539088861.py in <module>
# ----> 1 import quandl
#       2 quandl.ApiConfig.api_key = "fw5nDw6r11iFdURq7ya3"
#       3 data = quandl.get_table('MER/F1', compnumber = "39102", paginate = True)
#       4 print(data)
#
# ModuleNotFoundError: No module named 'quandl'

# %%
print("hello")
# Out:
# hello

# %%
import numpy as np
import matplotlib.pylab as plt
import matplotlib

t = np.arange(0.0, 2.0, 0.001)
s = 1 + np.sin(2*np.pi*t)
fig, ax = plt.subplots()
ax.plot(t, s)

ax.set(xlabel = 'time(s)', ylabel = 'voltage (mV)', title = 'Voltage Plot')
ax.grid()

# %%
import quandl
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6380\293843516.py in <module>
# ----> 1 import quandl
#
# ModuleNotFoundError: No module named 'quandl'

# %%
pip show
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: ERROR: Please provide a package name or names.
